# %%
import json

expenses = []
filename = "expenses.json"

def load_expenses():
    global expenses
    try:
        with open(filename, "r") as file:
            expenses = json.load(file)
    except:
        expenses = []

def save_expenses():
    with open(filename, "w") as file:
        json.dump(expenses, file)

def add_expense():
    try:
        date = input("Enter Date (DD-MM-YYYY): ")
        category = input("Enter Category: ")
        amount = float(input("Enter Amount: "))

        expense = {
            "date": date,
            "category": category,
            "amount": amount
        }

        expenses.append(expense)
        save_expenses()

        print("Expense added successfully!")

    except ValueError:
        print("Invalid amount!")

def view_expenses():

    if len(expenses) == 0:
        print("No expenses recorded.")
        return

    print("\nAll Expenses")
    for exp in expenses:
        print(exp["date"], "-", exp["category"], "- ₹", exp["amount"])

def total_expense():

    total = 0

    for exp in expenses:
        total += exp["amount"]

    print("Total Spending: ₹", total)

# Main Program
load_expenses()

while True:

    print("\n===== Expense Tracker =====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Calculate Total")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_expense()

    elif choice == "2":
        view_expenses()

    elif choice == "3":
        total_expense()

    elif choice == "4":
        print("Program Ended")
        break

    else:
        print("Invalid choice")
# Out:
# ===== Expense Tracker =====
# 1. Add Expense
# 2. View Expenses
# 3. Calculate Total
# 4. Exit
# Enter your choice: 70000
# Invalid choice
#
# ===== Expense Tracker =====
# 1. Add Expense
# 2. View Expenses
# 3. Calculate Total
# 4. Exit
# Enter your choice: 1
# Enter Date (DD-MM-YYYY): 21-09-2000
# Enter Category: birthday
# Enter Amount: 10000
# Expense added successfully!
#
# ===== Expense Tracker =====
# 1. Add Expense
# 2. View Expenses
# 3. Calculate Total
# 4. Exit
# Enter your choice: 1
# Enter Date (DD-MM-YYYY): 19-03-2000
# Enter Category: festival
# Enter Amount: 8000
# Expense added successfully!
#
# ===== Expense Tracker =====
# 1. Add Expense
# 2. View Expenses
# 3. Calculate Total
# 4. Exit
# Enter your choice: 3
# Total Spending: ₹ 18000.0
#
# ===== Expense Tracker =====
# 1. Add Expense
# 2. View Expenses
# 3. Calculate Total
# 4. Exit
# Enter your choice: 2
#
# All Expenses
# 21-09-2000 - birthday - ₹ 10000.0
# 19-03-2000 - festival - ₹ 8000.0
#
# ===== Expense Tracker =====
# 1. Add Expense
# 2. View Expenses
# 3. Calculate Total
# 4. Exit
# Enter your choice: 4
# Program Ended
